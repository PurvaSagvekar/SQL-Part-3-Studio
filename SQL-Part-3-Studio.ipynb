-- %% [markdown]
-- # SQL Part 3 Studio
--
-- ### Let's practice your SQL quering skills!  For each question, work along in the notebook adding your query and answering the questions.
--
-- ### **DataSet**
--
-- ### <span style="font-size: 14px; font-family: -apple-system, BlinkMacSystemFont, sans-serif;">We will be using the Goodbooks-10k dataset from the exercises in the prep work.&nbsp; Feel free reference your previous notebooks.</span>
--
-- - The dataset can be found here: [goodbooks-10k](https://www.kaggle.com/zygmunt/goodbooks-10k)
-- - You can access the **BooksDB** in the Launchcode server.
--
-- ### **Business Issue**
--
-- You are an employee at a small independet bookstore and you have been tasked to increase sales.  You decide to use the BooksDB to find books and themes to highlight in fun promotions throughout each month / season.  We will be starting with March and then you will have a chance to explore another month of your choosing.  We want to come up with a list of events/ promotions to run each month.  If you are looking for ideas to include in your promotions:
--
-- - [https://www.calendarr.com/united-states/calendar-2022/](https://www.calendarr.com/united-states/calendar-2022/)
-- - [https://www.holidayinsights.com/moreholidays/](https://www.holidayinsights.com/moreholidays/)
--     - Click on a month and it will take you to a more detailed page

-- %% [markdown]
-- ## Part 1:  March - Women's History Month, Dr Seuss Day(3/2), National Pie Day3/14, St Patrick's Day (3/17), Season - Spring

-- %% [markdown]
-- ### **Event 1:** Women's History Month
--
-- Goal: Highlight Popular Womans Authors based on ratings from the Good Reads DB.
--
-- ### **Write a query that returns tag\_id, the number of times each tag\_id is used and the tag\_name.**
--
-- ### Use the GROUP BY and HAVING clause to narrow your focus.
--
-- Try multiple keywords, ie woman vs female (female ended up giving better results)

-- %%
-- Solution
SELECT b.title,b.best_book_id,c.tag_id,c.goodreads_book_id
from BooksDB.dbo.books as b 
JOIN BooksDB.dbo.book_tags as c
on b.best_book_id = c.tag_id
-- Where b.title like '%mystery%'
-- GROUP BY b.best_book_id
-- having b.best_book_id = %1%
ORDER by c.tag_id
-- Out:
-- (85776 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:01.635
-- <table><tr><th>title</th><th>best_book_id</th><th>tag_id</th><th>goodreads_book_id</th></tr><tr><td>Harry Potter and the Half-Blood Prince (Harry Potter, #6)</td><td>1</td><td>1</td><td>1207904</td></tr><tr><td>Harry Potter and the Half-Blood Prince (Harry Potter, #6)</td><td>1</td><td>1</td><td>43799</td></tr><tr><td>Harry Potter and the Order of the Phoenix (Harry Potter, #5)</td><td>2</td><td>2</td><td>513367</td></tr><tr><td>Harry Potter and the Sorcerer&#39;s Stone (Harry Potter, #1)</td><td>3</td><td>3</td><td>5552</td></tr><tr><td>Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)</td><td>5</td><td>5</td><td>79006</td></tr><tr><td>Harry Potter and the Goblet of Fire (Harry Potter, #4)</td><td>6</td><td>6</td><td>79006</td></tr><tr><td>Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)</td><td>8</td><td>8</td><td>168814</td></tr><tr><td>Harry Potter Collection (Harry Potter, #1-6)</td><td>10</td><td>10</td><td>43799</td></tr><tr><td>The Ultimate Hitchhiker&#39;s Guide to the Galaxy</td><td>13</td><td>13</td><td>1207904</td></tr><tr><td>A Short History of Nearly Everything</td><td>21</td><td>21</td><td>36058</td></tr><tr><td>A Short History of Nearly Everything</td><td>21</td><td>21</td><td>7519866</td></tr><tr><td>In a Sunburned Country</td><td>24</td><td>24</td><td>22320</td></tr><tr><td>I&#39;m a Stranger Here Myself: Notes on Returning to America after Twenty Years Away</td><td>25</td><td>25</td><td>4673605</td></tr><tr><td>The Lost Continent: Travels in Small Town America</td><td>26</td><td>26</td><td>43886</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>2798094</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>1406197</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>6098691</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>64860</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>21685</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>21683</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>85391</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>6726595</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>337623</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>43886</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>46917</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>19674</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>11666</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>154424</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>6588</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>643962</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>79379</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>7853757</td></tr><tr><td>Neither Here nor There: Travels in Europe</td><td>27</td><td>27</td><td>7313444</td></tr><tr><td>Notes from a Small Island</td><td>28</td><td>28</td><td>1205297</td></tr><tr><td>The Mother Tongue: English and How It Got That Way</td><td>29</td><td>29</td><td>81176</td></tr><tr><td>J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings</td><td>30</td><td>30</td><td>32446</td></tr><tr><td>J.R.R. Tolkien 4-Book Boxed Set: The Hobbit and The Lord of the Rings</td><td>30</td><td>30</td><td>11166889</td></tr><tr><td>The Lord of the Rings (The Lord of the Rings, #1-3)</td><td>33</td><td>33</td><td>1205297</td></tr><tr><td>The Fellowship of the Ring (The Lord of the Rings, #1)</td><td>34</ ...

-- %% [markdown]
-- ### **Which keyword(s) and tag(s) would you like to explore more?**
--
-- Double click to edit.

-- %% [markdown]
-- ### **Write a query to return authors, titles, ratings and** **selected tag(s)\_id.**

-- %%
-- Solution
SELECT b.authors,b.title,b.ratings_4,b.book_id,t.tag_id
from BooksDB.dbo.books as b
INNER JOIN BooksDB.dbo.book_tags as t 
on b.book_id = t.tag_id
WHERE b.title like '%Harry Potter%'
-- group BY t.tag_id
-- having t.tag_id = 15881
-- Out:
-- (30 rows affected)
-- Total execution time: 00:00:00.180
-- <table><tr><th>authors</th><th>title</th><th>ratings_4</th><th>book_id</th><th>tag_id</th></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td><td>548266</td><td>15881</td><td>15881</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Sorcerer&#39;s Stone (Harry Potter, #1)</td><td>1156318</td><td>3</td><td>3</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td><td>548266</td><td>15881</td><td>15881</td></tr><tr><td>David Baggett, Shawn E. Klein</td><td>Harry Potter and Philosophy: If Aristotle Ran Hogwarts</td><td>1641</td><td>31819</td><td>31819</td></tr><tr><td>David Baggett, Shawn E. Klein</td><td>Harry Potter and Philosophy: If Aristotle Ran Hogwarts</td><td>1641</td><td>31819</td><td>31819</td></tr><tr><td>David Baggett, Shawn E. Klein</td><td>Harry Potter and Philosophy: If Aristotle Ran Hogwarts</td><td>1641</td><td>31819</td><td>31819</td></tr><tr><td>David Baggett, Shawn E. Klein</td><td>Harry Potter and Philosophy: If Aristotle Ran Hogwarts</td><td>1641</td><td>31819</td><td>31819</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td><td>548266</td><td>15881</td><td>15881</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td><td>548266</td><td>15881</td><td>15881</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Half-Blood Prince (Harry Potter, #6)</td><td>459028</td><td>1</td><td>1</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter Collection (Harry Potter, #1-6)</td><td>3891</td><td>10</td><td>10</td></tr><tr><td>David Baggett, Shawn E. Klein</td><td>Harry Potter and Philosophy: If Aristotle Ran Hogwarts</td><td>1641</td><td>31819</td><td>31819</td></tr><tr><td>J.K. Rowling, Mary GrandPré, Rufus Beck</td><td>Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)</td><td>509447</td><td>5</td><td>5</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Goblet of Fire (Harry Potter, #4)</td><td>494926</td><td>6</td><td>6</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry</td><td>2595</td><td>2002</td><td>2002</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry</td><td>2595</td><td>2002</td><td>2002</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry</td><td>2595</td><td>2002</td><td>2002</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)</td><td>3686</td><td>8</td><td>8</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry</td><td>2595</td><td>2002</td><td>2002</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry</td><td>2595</td><td>2002</td><td>2002</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Order of the Phoenix (Harry Potter, #5)</td><td>494427</td><td>2</td><td>2</td></tr><tr><td>J.K. Rowling</td><td>Harry Potter Schoolbooks Box Set: Two Classic Books from the Library of Hogwarts School of Witchcraft and Wizardry</td><td>2595</td><td>2002</td><td>2002</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Chamber of Secrets (Harry Potter, #2)</td><td>548266</td><td>15881</td><td>15881</td></tr><tr><td>J.K. Rowling, Mary GrandPré</td><td>Harry Potter and the Half-Blood Prince (Harry Potter, #6)</td><td>459028</td><td>1</td><td>1</td></tr><tr><td>David Baggett, Shawn E. Klein</td><td>Harry Potter and Philoso ...

-- %% [markdown]
-- ### **Record your thoughts about why you wrote the query the way you did.**

-- %% [markdown]
-- # Part 2: Choose Another Month
--
-- Choose another month and plan at least 2 events / promotions and answer the following questions.
--
-- Which month did you choose?
--
-- What 2 events / promotions are you highlighting?
--
-- > 1.
--
-- > 2.

-- %% [markdown]
-- # Part 3: Summarize your Work
--
-- For each event write at least one query that joins any two tables in the BooksDB to support your choice and record you thoughts as to why you used the paticlular query. At least one of your queries needs to include a HAVING clause.

-- %%
-- Event 1 Query

-- %% [markdown]
-- ### **Summary of event 1:**
--
-- Double Click to edit.

-- %%
-- Event 2 Query

-- %% [markdown]
-- ### **Summary of event 2:**
--
-- Double Click to edit.
